# %% [markdown]
# # 1、全国哪些城市对大模型岗位需求比较高，基于招聘数据，可视化招聘岗位数量全国各城市地域分布图（以市级为行政单元，不要用省份）

# %%
import pandas as pd
import numpy as np
from pyecharts import options as opts
from pyecharts.charts import Map, Bar, Pie, WordCloud, Page
from pyecharts.globals import ThemeType
import re
# %pip install pyecharts
# %matplotlib inline
# Out:
# Requirement already satisfied: pyecharts in d:\eage\programe files\anaconda3\lib\site-packages (2.0.4)
# Requirement already satisfied: jinja2 in d:\eage\programe files\anaconda3\lib\site-packages (from pyecharts) (3.1.2)
# Requirement already satisfied: prettytable in d:\eage\programe files\anaconda3\lib\site-packages (from pyecharts) (3.9.0)
# Requirement already satisfied: simplejson in d:\eage\programe files\anaconda3\lib\site-packages (from pyecharts) (3.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\eage\programe files\anaconda3\lib\site-packages (from jinja2->pyecharts) (2.1.1)
# Requirement already satisfied: wcwidth in d:\eage\programe files\anaconda3\lib\site-packages (from prettytable->pyecharts) (0.2.5)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 替换为你实际的 CSV 路径
file_path = "大模型岗位信息.csv"
df = pd.read_csv(file_path)

# 处理薪资数据
def extract_salary(salary_str):
    if pd.isna(salary_str):
        return np.nan
    numbers_str = re.findall(r'\d+', salary_str)
    min_salary = max_salary = np.nan
    months_per_year = 12
    if len(numbers_str) >= 2:
        try:
            min_salary_k = int(numbers_str[0])
            max_salary_k = int(numbers_str[1])
            min_salary = min_salary_k * 1000
            max_salary = max_salary_k * 1000
            if len(numbers_str) >= 3:
                try:
                    months_per_year = int(numbers_str[2])
                except:
                    pass
            avg_monthly_salary = ((min_salary + max_salary) / 2) * months_per_year / 12
            return avg_monthly_salary
        except:
            return np.nan
    return np.nan

def extract_city(location):
    if pd.isna(location):
        return np.nan
    city = location.split('-')[0].strip().replace(' ', '')
    return city

def process_tags(tags):
    if pd.isna(tags):
        return []
    return [tag.strip() for tag in tags.split(',')]
# 应用处理函数
df['平均月薪'] = df['岗位薪资'].apply(extract_salary)
df['城市'] = df['工作地点'].apply(extract_city)
df['岗位标签列表'] = df['岗位标签'].apply(process_tags)

# %%
df.head()
# Out:
#                             岗位名称    工作地点        岗位薪资   经验要求  学历要求  \
# 0        阿里云智能-AI/AIGC国际标准化专家-北京      北京      10-20k   经验不限    本科
# 1  增长策略产品经理 (AIGC方向)-UG Paid Ads  北京-朝阳区  25-45k·15薪   经验不限    本科
# 2                        AIGC科学家      北京      40-70k   经验不限    硕士
# 3                       AIGC后端开发  北京-顺义区  15-25k·13薪  5-10年    大专
# 4                AIGC产品经理-某短视频大厂      北京  25-50k·15薪   经验不限  统招本科
#
#                                                 岗位标签           企业名称   企业行业  \
# 0                                            Unknown            阿里云    互联网
# 1             增长产品,数据产品,客户端产品,内容产品,AI人工智能产品,短视频,数据分析           字节跳动    互联网
# 2                                     技术支持,技术战略,团队管理  北京微播易科技股份有限公司    互联网
# 3         语言模型,算法研究,Java,Python,机器视觉,大数据算法,AIGC,人工智能      某北京其他金融公司   其他金融
# 4  AI人工智能产品,推荐产品,人工智能,智能推荐,to C,to G,团队管理,产品设计,需求...          某知名公司  计算机软件
#
#        企业规模   融资状况          平均月薪  城市  \
# 0  10000人以上  融资未公开  15000.000000  北京
# 1  10000人以上     其他  43750.000000  北京
# 2  100-499人     D轮  55000.000000  北京
# 3  100-499人   战略融资  21666.666667  北京
# 4  100-499人     A轮  46875.000000  北京
#
#                                               岗位标签列表 城市_clean
# 0                                          [Unknown]       北京
# 1     [增长产品, 数据产品, 客户端产品, 内容产品, AI人工智能产品, 短视频, 数据分析]       北京
# 2                                 [技术支持, 技术战略, 团队管理]       北京
# 3  [语言模型, 算法研究, Java, Python, 机器视觉, 大数据算法, AIGC, ...       北京
# 4  [AI人工智能产品, 推荐产品, 人工智能, 智能推荐, to C, to G, 团队管理,...       北京

# %% [markdown]
# ## 城市岗位地图

# %%
from pyecharts.commons.utils import JsCode
# 去除“市”字，仅保留城市名
df['城市_clean'] = df['城市'].str.replace("市", "").str.replace("区", "").str.replace("县", "").str.strip()

from pyecharts import options as opts
from pyecharts.charts import Map

# 统计岗位数量
city_counts = df['城市_clean'].value_counts().to_dict()
city_counts = {k + "市" if not k.endswith("市") else k: v for k, v in city_counts.items()}
# 构造地图
map_city_job = (
    Map()
    .add(
        "岗位数量",
        [list(z) for z in city_counts.items()],
        maptype="china-cities",  # 关键：启用市级地图
        label_opts=opts.LabelOpts(
    is_show=True,
    formatter=JsCode("""
        function(params){
            if (params.value > 0) {
                return params.name;
            } else {
                return '';
            }
        }
    """)
)
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="全国大模型岗位需求城市分布（市级）"),
        visualmap_opts=opts.VisualMapOpts(
            is_piecewise=True,
            pieces=[
                {"min": 100, "label": "100以上", "color": "#FF0000"},
                {"min": 50, "max": 99, "label": "50-99", "color": "#FFA07A"},
                {"min": 20, "max": 49, "label": "20-49", "color": "#FFD700"},
                {"min": 10, "max": 19, "label": "10-19", "color": "#98FB98"},
                {"min": 1, "max": 9, "label": "1-9", "color": "#87CEFA"},
                {"value": 0, "label": "无数据", "color": "#EEEEEE"}
            ]
        )
    )
)

# Jupyter 内嵌显示
map_city_job.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china-cities':'https://assets.pyecharts.org/assets/v5/maps/china-cities'
#         }
#     });
# </script>
#
#         <div id="e492ac88a6bd45478b6eaf056df8b81e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china-cities'], function(echarts) {
#                 var chart_e492ac88a6bd45478b6eaf056df8b81e = echarts.init(
#                     document.getElementById('e492ac88a6bd45478b6eaf056df8b81e'), 'white', {renderer: 'canvas'});
#                 var option_e492ac88a6bd45478b6eaf056df8b81e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5c97\u4f4d\u6570\u91cf",
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter":         function(params){            if (params.value > 0) {                return params.name;            } else {                return '';            }        }
#             },
#             "map": "china-cities",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac\u5e02",
#                     "value": 1072
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u5e02",
#                     "value": 957
#                 },
#                 {
#                     "name": "\u6df1\u5733\u5e02",
#                     "value": 875
#                 },
#                 {
#                     "name": "\u676d\u5dde\u5e02",
#                     "value": 810
#                 },
#                 {
#                     "name": "\u5e7f\u5dde\u5e02",
#                     "value": 422
#                 },
#                 {
#                     "name": "\u5357\u4eac\u5e02",
#                     "value": 302
#                 },
#                 {
#                     "name": "\u6210\u90fd\u5e02",
#                     "value": 246
#                 },
#                 {
#                     "name": "\u6b66\u6c49\u5e02",
#                     "value": 220
#                 },
#                 {
#                     "name": "\u82cf\u5dde\u5e02",
#                     "value": 158
#                 },
#                 {
#                     "name": "\u91cd\u5e86\u5e02",
#                     "value": 121
#                 },
#                 {
#                     "name": "\u897f\u5b89\u5e02",
#                     "value": 86
#                 },
#                 {
#                     "name": "\u5929\u6d25\u5e02",
#                     "value": 52
#                 },
#                 {
#                     "name": "\u5927\u8fde\u5e02",
#                     "value": 12
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "zlevel": 0,
#             "z": 2,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5c97\u4f4d\u6570\u91cf"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\u5168\u56fd\u5927\u6a21\u578b\u5c97\u4f4d\u9700\u6c42\u57ce\u5e02\u5206\u5e03\uff08\u5e02\u7ea7\uff09",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "hoverLink": true,
#         "orient": "vertical",
#         "padding": 5,
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0,
#         "pieces": [
#             {
#                 "min": 100,
#                 "label": "100\u4ee5\u4e0a",
#                 "color": "#FF0000"
#             },
#             {
#                 "min": 50,
#                 "max": 99,
#                 "label": "50-99",
#                 "color": "#FFA07A"
#             },
#             {
#                 "min": 20,
#                 "max": 49,
#                 "label": "20-49",
#                 "color": "#FFD700"
#             },
#             {
#                 "min": 10,
#                 "max": 19,
#                 "label": "10-19",
#                 "color": "#98FB98"
#             },
#             {
#                 "min": 1,
#                 "max": 9,
#                 "label": "1-9",
#                 "color": "#87CEFA"
#             },
#             {
#                 "value": 0,
#                 "label": "\u65e0\u6570\u636e",
#                 "color": "#EEEEEE"
#             }
#         ]
#     }
# };
#                 chart_e492ac88a6bd45478b6eaf056df8b81e.setOption(option_e492ac88a6bd45478b6eaf056df8b81e);
#         });
#     </script>

# %%
city_counts = {k + "市" if not k.endswith("市") else k: v for k, v in city_counts.items()}
city_counts
# Out:
# {'北京市': 1072,
#  '上海市': 957,
#  '深圳市': 875,
#  '杭州市': 810,
#  '广州市': 422,
#  '南京市': 302,
#  '成都市': 246,
#  '武汉市': 220,
#  '苏州市': 158,
#  '重庆市': 121,
#  '西安市': 86,
#  '天津市': 52,
#  '大连市': 12}

# %% [markdown]
# # 2、（可选）全国哪些城市薪资待遇比较好，基于招聘薪资待遇情况，转换为平均月薪，可视化平均薪资待遇全国各城市地域分布图（以市级为行政单元，不要用省份）

# %%
city_salary = df.dropna(subset=['平均月薪']).groupby('城市')['平均月薪'].mean().round(2).to_dict()
city_salary = city_counts = {k + "市" if not k.endswith("市") else k: v for k, v in city_salary.items()}
max_salary_val = max(city_salary.values()) if city_salary else 150000

map_salary = (
    Map()
    .add("平均月薪", [list(z) for z in city_salary.items()],maptype="china-cities",
        label_opts=opts.LabelOpts(
    is_show=True,
    formatter=JsCode("""
        function(params){
            if (params.value > 0) {
                return params.name;
            } else {
                return '';
            }
        }
    """)
))
    .set_global_opts(
        title_opts=opts.TitleOpts(title="全国大模型岗位平均薪资分布"),
        visualmap_opts=opts.VisualMapOpts(
            min_=0,
            max_=max_salary_val,
            is_piecewise=True,
            pieces=[
                {"min": 100000, "label": "100k以上", "color": "#8A0808"},
                {"min": 80000, "max": 99999, "label": "80k-99.9k", "color": "#CD0A0A"},
                {"min": 60000, "max": 79999, "label": "60k-79.9k", "color": "#FF0000"},
                {"min": 40000, "max": 59999, "label": "40k-59.9k", "color": "#FFA07A"},
                {"min": 30000, "max": 39999, "label": "30k-39.9k", "color": "#FFD700"},
                {"min": 20000, "max": 29999, "label": "20k-29.9k", "color": "#98FB98"},
                {"min": 10000, "max": 19999, "label": "10k-19.9k", "color": "#87CEFA"},
                {"min": 0, "max": 9999, "label": "0-9.9k", "color": "#ADD8E6"},
            ]
        )
    )
)
map_salary.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china-cities':'https://assets.pyecharts.org/assets/v5/maps/china-cities'
#         }
#     });
# </script>
#
#         <div id="7f522a83d25e472b9293d0aa3abb0ede" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china-cities'], function(echarts) {
#                 var chart_7f522a83d25e472b9293d0aa3abb0ede = echarts.init(
#                     document.getElementById('7f522a83d25e472b9293d0aa3abb0ede'), 'white', {renderer: 'canvas'});
#                 var option_7f522a83d25e472b9293d0aa3abb0ede = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5e73\u5747\u6708\u85aa",
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter":         function(params){            if (params.value > 0) {                return params.name;            } else {                return '';            }        }
#             },
#             "map": "china-cities",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77\u5e02",
#                     "value": 58328.52
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02",
#                     "value": 61186.56
#                 },
#                 {
#                     "name": "\u5357\u4eac\u5e02",
#                     "value": 43523.13
#                 },
#                 {
#                     "name": "\u5927\u8fde\u5e02",
#                     "value": 19916.67
#                 },
#                 {
#                     "name": "\u5929\u6d25\u5e02",
#                     "value": 30584.97
#                 },
#                 {
#                     "name": "\u5e7f\u5dde\u5e02",
#                     "value": 43284.2
#                 },
#                 {
#                     "name": "\u6210\u90fd\u5e02",
#                     "value": 39028.24
#                 },
#                 {
#                     "name": "\u676d\u5dde\u5e02",
#                     "value": 54233.56
#                 },
#                 {
#                     "name": "\u6b66\u6c49\u5e02",
#                     "value": 39047.84
#                 },
#                 {
#                     "name": "\u6df1\u5733\u5e02",
#                     "value": 59063.87
#                 },
#                 {
#                     "name": "\u82cf\u5dde\u5e02",
#                     "value": 44086.27
#                 },
#                 {
#                     "name": "\u897f\u5b89\u5e02",
#                     "value": 33713.35
#                 },
#                 {
#                     "name": "\u91cd\u5e86\u5e02",
#                     "value": 45658.05
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "zlevel": 0,
#             "z": 2,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e73\u5747\u6708\u85aa"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\u5168\u56fd\u5927\u6a21\u578b\u5c97\u4f4d\u5e73\u5747\u85aa\u8d44\u5206\u5e03",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 61186.56,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "hoverLink": true,
#         "orient": "vertical",
#         "padding": 5,
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0,
#         "pieces": [
#             {
#                 "min": 100000,
#                 "label": "100k\u4ee5\u4e0a",
#                 "color": "#8A0808"
#             },
#             {
#                 "min": 80000,
#                 "max": 99999,
#                 "label": "80k-99.9k",
#                 "color": "#CD0A0A"
#             },
#             {
#                 "min": 60000,
#                 "max": 79999,
#                 "label": "60k-79.9k",
#                 "color": "#FF0000"
#             },
#             {
#                 "min": 40000,
#                 "max": 59999,
#                 "label": "40k-59.9k",
#                 "color": "#FFA07A"
#             },
#             {
#                 "min": 30000,
#                 "max": 39999,
#                 "label": "30k-39.9k",
#                 "color": "#FFD700"
#             },
#             {
#                 "min": 20000,
#                 "max": 29999,
#                 "label": "20k-29.9k",
#                 "color": "#98FB98"
#             },
#             {
#                 "min": 10000,
#                 "max": 19999,
#                 "label": "10k-19.9k",
#                 "color": "#87CEFA"
#             },
#             {
#                 "min": 0,
#                 "max": 9999,
#                 "label": "0-9.9k",
#                 "color": "#ADD8E6"
#             }
#         ]
#     }
# };
#                 chart_7f522a83d25e472b9293d0aa3abb0ede.setOption(option_7f522a83d25e472b9293d0aa3abb0ede);
#         });
#     </script>

# %%
city_salary = df.dropna(subset=['平均月薪']).groupby('城市')['平均月薪'].mean().round(2).to_dict()
city_salary = city_counts = {k + "市" if not k.endswith("市") else k: v for k, v in city_salary.items()}
city_salary
# Out:
# {'上海市': 58328.52,
#  '北京市': 61186.56,
#  '南京市': 43523.13,
#  '大连市': 19916.67,
#  '天津市': 30584.97,
#  '广州市': 43284.2,
#  '成都市': 39028.24,
#  '杭州市': 54233.56,
#  '武汉市': 39047.84,
#  '深圳市': 59063.87,
#  '苏州市': 44086.27,
#  '西安市': 33713.35,
#  '重庆市': 45658.05}

# %%
df.dropna(subset=['平均月薪']).groupby('城市')['平均月薪'].mean().round(2).to_dict()
# Out:
# {'上海': 58328.52,
#  '北京': 61186.56,
#  '南京': 43523.13,
#  '大连': 19916.67,
#  '天津': 30584.97,
#  '广州': 43284.2,
#  '成都': 39028.24,
#  '杭州': 54233.56,
#  '武汉': 39047.84,
#  '深圳': 59063.87,
#  '苏州': 44086.27,
#  '西安': 33713.35,
#  '重庆': 45658.05}

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar, Line
from pyecharts.globals import ThemeType


# 统一城市顺序：按岗位数排序
common_cities = sorted(city_counts.items(), key=lambda x: x[1], reverse=True)
cities = [c[0] for c in common_cities]
counts = [city_counts[c] for c in cities]
salaries = [city_salary.get(c, 0) for c in cities]  # 如果城市没薪资数据则补0

# 创建图表对象
bar = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT, width="1000px"))
    .add_xaxis(cities)
    .add_yaxis("岗位数量", counts, yaxis_index=0)
    .extend_axis(
        yaxis=opts.AxisOpts(
            name="平均薪资（元）",
            type_="value",
            min_=0,
            position="right",
            axislabel_opts=opts.LabelOpts(formatter="{value}"),
        )
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="城市岗位数量与平均薪资对比"),
        yaxis_opts=opts.AxisOpts(
            name="岗位数量",
            position="left",
            axislabel_opts=opts.LabelOpts(formatter="{value}")
        ),
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=45)),
        tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
        datazoom_opts=[opts.DataZoomOpts(), opts.DataZoomOpts(type_="inside")]
    )
)

# 添加折线图到次坐标轴（右侧）
line = (
    Line()
    .add_xaxis(cities)
    .add_yaxis("平均薪资", salaries, yaxis_index=1)
)

# 叠加图表
bar.overlap(line).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9dbe2d5121b849ddb84f9bc5b7ccbff8" style="width:1000px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9dbe2d5121b849ddb84f9bc5b7ccbff8 = echarts.init(
#                     document.getElementById('9dbe2d5121b849ddb84f9bc5b7ccbff8'), 'light', {renderer: 'canvas'});
#                 var option_9dbe2d5121b849ddb84f9bc5b7ccbff8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5c97\u4f4d\u6570\u91cf",
#             "yAxisIndex": 0,
#             "legendHoverLink": true,
#             "data": [
#                 1072,
#                 957,
#                 875,
#                 810,
#                 422,
#                 302,
#                 246,
#                 220,
#                 158,
#                 121,
#                 86,
#                 52,
#                 12
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5e73\u5747\u85aa\u8d44",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u5317\u4eac\u5e02",
#                     61186.56
#                 ],
#                 [
#                     "\u4e0a\u6d77\u5e02",
#                     58328.52
#                 ],
#                 [
#                     "\u6df1\u5733\u5e02",
#                     59063.87
#                 ],
#                 [
#                     "\u676d\u5dde\u5e02",
#                     54233.56
#                 ],
#                 [
#                     "\u5e7f\u5dde\u5e02",
#                     43284.2
#                 ],
#                 [
#                     "\u5357\u4eac\u5e02",
#                     43523.13
#                 ],
#                 [
#                     "\u6210\u90fd\u5e02",
#                     39028.24
#                 ],
#                 [
#                     "\u6b66\u6c49\u5e02",
#                     39047.84
#                 ],
#                 [
#                     "\u82cf\u5dde\u5e02",
#                     44086.27
#                 ],
#                 [
#                     "\u91cd\u5e86\u5e02",
#                     45658.05
#                 ],
#                 [
#                     "\u897f\u5b89\u5e02",
#                     33713.35
#                 ],
#                 [
#                     "\u5929\u6d25\u5e02",
#                     30584.97
#                 ],
#                 [
#                     "\u5927\u8fde\u5e02",
#                     19916.67
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5c97\u4f4d\u6570\u91cf",
#                 "\u5e73\u5747\u85aa\u8d44"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "axis",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "cross"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "rotate": 45,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5317\u4eac\u5e02",
#                 "\u4e0a\u6d77\u5e02",
#                 "\u6df1\u5733\u5e02",
#                 "\u676d\u5dde\u5e02",
#                 "\u5e7f\u5dde\u5e02",
#                 "\u5357\u4eac\u5e02",
#                 "\u6210\u90fd\u5e02",
#                 "\u6b66\u6c49\u5e02",
#                 "\u82cf\u5dde\u5e02",
#                 "\u91cd\u5e86\u5e02",
#                 "\u897f\u5b89\u5e02",
#                 "\u5929\u6d25\u5e02",
#                 "\u5927\u8fde\u5e02"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u5c97\u4f4d\u6570\u91cf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{value}"
#             },
#             "inverse": false,
#             "position": "left",
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         },
#         {
#             "type": "value",
#             "name": "\u5e73\u5747\u85aa\u8d44\uff08\u5143\uff09",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,

# %%
df
# Out:
#                                岗位名称    工作地点        岗位薪资   经验要求  学历要求  \
# 0           阿里云智能-AI/AIGC国际标准化专家-北京      北京      10-20k   经验不限    本科
# 1     增长策略产品经理 (AIGC方向)-UG Paid Ads  北京-朝阳区  25-45k·15薪   经验不限    本科
# 2                           AIGC科学家      北京      40-70k   经验不限    硕士
# 3                          AIGC后端开发  北京-顺义区  15-25k·13薪  5-10年    大专
# 4                   AIGC产品经理-某短视频大厂      北京  25-50k·15薪   经验不限  统招本科
# ...                             ...     ...         ...    ...   ...
# 5328                      AI解决方案架构师  西安-高新区  24-35k·14薪  5-10年  统招本科
# 5329                        AI算法工程师  西安-长安区  15-20k·14薪   3-5年    硕士
# 5330                       NLP算法工程师  西安-长安区      10-15k   3-5年  统招本科
# 5331                        AI算法工程师  西安-高新区      10-16k   1-3年  统招本科
# 5332                        AI算法工程师      西安      12-18k   经验不限  统招本科
#
#                                                    岗位标签           企业名称   企业行业  \
# 0                                               Unknown            阿里云    互联网
# 1                增长产品,数据产品,客户端产品,内容产品,AI人工智能产品,短视频,数据分析           字节跳动    互联网
# 2                                        技术支持,技术战略,团队管理  北京微播易科技股份有限公司    互联网
# 3            语言模型,算法研究,Java,Python,机器视觉,大数据算法,AIGC,人工智能      某北京其他金融公司   其他金融
# 4     AI人工智能产品,推荐产品,人工智能,智能推荐,to C,to G,团队管理,产品设计,需求...          某知名公司  计算机软件
# ...                                                 ...            ...    ...
# 5328                             需求分析,软件开发,云计算领域,人工智能领域           科大讯飞  计算机软件
# 5329          C++,Python,图像开发,人工智能领域,TensorFlow,PyTorch           瞰觅科技   人工智能
# 5330                             自然语言处理,深度学习,Python,nlp           软通动力    互联网
# 5331                                        深度学习,深度学习框架  深圳市讯方技术股份有限公司   IT服务
# 5332       算法开发,算法优化,算法设计,Python,深度学习,机器视觉,大数据算法,自然语言处理          某上市公司  计算机软件
#
#             企业规模     融资状况          平均月薪  城市  \
# 0       10000人以上    融资未公开  15000.000000  北京
# 1       10000人以上       其他  43750.000000  北京
# 2       100-499人       D轮  55000.000000  北京
# 3       100-499人     战略融资  21666.666667  北京
# 4       100-499人       A轮  46875.000000  北京
# ...          ...      ...           ...  ..
# 5328    10000人以上      已上市  34416.666667  西安
# 5329    100-499人    融资未公开  20416.666667  西安
# 5330    10000人以上  Unknown  12500.000000  西安
# 5331  2000-5000人    新三板上市  13000.000000  西安
# 5332    10000人以上  Unknown  15000.000000  西安
#
#                                                  岗位标签列表 城市_clean
# 0                                             [Unknown]       北京
# 1        [增长产品, 数据产品, 客户端产品, 内容产品, AI人工智能产品, 短视频, 数据分析]       北京
# 2                                    [技术支持, 技术战略, 团队管理]       北京
# 3     [语言模型, 算法研究, Java, Python, 机器视觉, 大数据算法, AIGC, ...       北京
# 4     [AI人工智能产品, 推荐产品, 人工智能, 智能推荐, to C, to G, 团队管理,...       北京
# ...                                                 ...      ...
# 5328                        [需求分析, 软件开发, 云计算领域, 人工智能领域]       西安
# 5329   [C++, Python, 图像开发, 人工智能领域, TensorFlow, PyTorch]       西安
# 5330                        [自然语言处理, 深度学习, Python, nlp]       西安
# 5331                                     [深度学习, 深度学习框架]       西安
# 5332  [算法开发, 算法优化, 算法设计, Python, 深度学习, 机器视觉, 大数据算法, ...       西安
#
# [5333 rows x 14 columns]

# %% [markdown]
# # 3、统计所有企业招聘岗位需求数量，并可视化展示招聘岗位数量排名Top20的企业
# 注意：岗位数量Top20的企业柱状图，需要添加区域缩放（全局配置项DataZoomOpts），支持拖拽轴的滑动查看企业排名情况

# %%
company_counts = df['企业名称'].value_counts().head(20)
bar_company = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add_xaxis(company_counts.index.tolist())
    .add_yaxis("岗位数量", company_counts.values.tolist())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Top20企业招聘岗位数量"),
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=45)),
        datazoom_opts=[opts.DataZoomOpts(), opts.DataZoomOpts(type_="inside")],
        yaxis_opts=opts.AxisOpts(name="岗位数量")
    )
)
bar_company.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9833b2abff3545d9838a5d650d1f08c7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9833b2abff3545d9838a5d650d1f08c7 = echarts.init(
#                     document.getElementById('9833b2abff3545d9838a5d650d1f08c7'), 'light', {renderer: 'canvas'});
#                 var option_9833b2abff3545d9838a5d650d1f08c7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5c97\u4f4d\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 389,
#                 172,
#                 110,
#                 72,
#                 67,
#                 59,
#                 59,
#                 57,
#                 57,
#                 53,
#                 50,
#                 50,
#                 48,
#                 41,
#                 40,
#                 38,
#                 37,
#                 36,
#                 34,
#                 33
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5c97\u4f4d\u6570\u91cf"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "rotate": 45,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u67d0\u77e5\u540d\u516c\u53f8",
#                 "\u5b57\u8282\u8df3\u52a8",
#                 "\u963f\u91cc\u5df4\u5df4\u96c6\u56e2",
#                 "Baidu",
#                 "\u67d0\u676d\u5dde\u5927\u578b\u8ba1\u7b97\u673a\u8f6f\u4ef6\u516c\u53f8",
#                 "\u8682\u8681\u96c6\u56e2",
#                 "\u534e\u4e3a",
#                 "\u67d0\u676d\u5dde\u4e92\u8054\u7f51\u4e0a\u5e02\u516c\u53f8",
#                 "\u67d0\u5317\u4eac\u4e92\u8054\u7f51\u516c\u53f8",
#                 "\u67d0\u5317\u4eac\u5927\u578b\u4e92\u8054\u7f51\u516c\u53f8",
#                 "\u5546\u6c64\u79d1\u6280SenseTime",
#                 "\u817e\u8baf",
#                 "\u67d0\u6df1\u5733\u5927\u578b\u901a\u4fe1\u8bbe\u5907\u516c\u53f8",
#                 "\u963f\u91cc\u4e91",
#                 "\u67d0\u4e0a\u6d77\u5927\u578b\u4e92\u8054\u7f51\u516c\u53f8",
#                 "\u67d0\u5317\u4eac\u5927\u578b\u8ba1\u7b97\u673a\u8f6f\u4ef6\u516c\u53f8",
#                 "\u67d0\u5927\u578b\u77e5\u540d\u4e92\u8054\u7f51\u516c\u53f8",
#                 "\u67d0\u5317\u4eac\u901a\u4fe1\u8bbe\u5907\u4e0a\u5e02\u516c\u53f8",
#                 "\u8363\u8000\u7ec8\u7aef\u6709\u9650\u516c\u53f8",
#                 "\u67d0\u676d\u5dde\u8ba1\u7b97\u673a\u8f6f\u4ef6\u4e0a\u5e02\u516c\u53f8"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u5c97\u4f4d\u6570\u91cf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "Top20\u4f01\u4e1a\u62db\u8058\u5c97\u4f4d\u6570\u91cf",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "dataZoom": [
#         {
#             "show": true,
#             "type": "slider",
#             "showDetail": true,
#             "showDataShadow": true,
#             "realtime": true,
#             "start": 20,
#             "end": 80,
#             "orient": "horizontal",
#             "zoomLock": false,
#             "filterMode": "filter"
#         },
#         {
#             "show": true,
#             "type": "inside",
#             "showDetail": true,
#             "showDataShadow": true,
#             "realtime": true,
#             "start": 20,
#             "end": 80,
#             "orient": "horizontal",
#             "zoomLock": false,
#             "filterMode": "filter"
#         }
#     ]
# };
#                 chart_9833b2abff3545d9838a5d650d1f08c7.setOption(option_9833b2abff3545d9838a5d650d1f08c7);
#         });
#     </script>

# %% [markdown]
# # 4、基于招聘岗位的学历要求，分析学历类别需求占比情况

# %%
education_counts = df['学历要求'].value_counts()
pie_edu = (
    Pie(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add("", [list(z) for z in education_counts.items()], radius=["40%", "75%"])
    .set_global_opts(
        title_opts=opts.TitleOpts(title="学历要求分布"),
        legend_opts=opts.LegendOpts(orient="vertical", pos_top="15%", pos_left="2%")
    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c} ({d}%)"))
)
pie_edu.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="adcd733b4fd94f8da53c36796db54f2f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_adcd733b4fd94f8da53c36796db54f2f = echarts.init(
#                     document.getElementById('adcd733b4fd94f8da53c36796db54f2f'), 'light', {renderer: 'canvas'});
#                 var option_adcd733b4fd94f8da53c36796db54f2f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u7855\u58eb",
#                     "value": 1905
#                 },
#                 {
#                     "name": "\u672c\u79d1",
#                     "value": 1533
#                 },
#                 {
#                     "name": "\u7edf\u62db\u672c\u79d1",
#                     "value": 1331
#                 },
#                 {
#                     "name": "\u5b66\u5386\u4e0d\u9650",
#                     "value": 343
#                 },
#                 {
#                     "name": "\u535a\u58eb",
#                     "value": 177
#                 },
#                 {
#                     "name": "\u5927\u4e13",
#                     "value": 44
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}: {c} ({d}%)"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7855\u58eb",
#                 "\u672c\u79d1",
#                 "\u7edf\u62db\u672c\u79d1",
#                 "\u5b66\u5386\u4e0d\u9650",
#                 "\u535a\u58eb",
#                 "\u5927\u4e13"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "2%",
#             "top": "15%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\u5b66\u5386\u8981\u6c42\u5206\u5e03",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_adcd733b4fd94f8da53c36796db54f2f.setOption(option_adcd733b4fd94f8da53c36796db54f2f);
#         });
#     </script>

# %% [markdown]
# # 5、岗位技能需求分析，基于表格给出的岗位标签信息，使用词云图统计分析

# %%
all_tags = []
for tags in df['岗位标签列表']:
    all_tags.extend(tags)
tag_counts = pd.Series(all_tags).value_counts()

wordcloud = (
    WordCloud(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add("", [list(z) for z in tag_counts.items()], word_size_range=[15, 80], shape="circle")
    .set_global_opts(title_opts=opts.TitleOpts(title="岗位技能需求词云"))
)
wordcloud.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/v5/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="6e4435b99c8841b5ab8ff4a5be31b6ba" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_6e4435b99c8841b5ab8ff4a5be31b6ba = echarts.init(
#                     document.getElementById('6e4435b99c8841b5ab8ff4a5be31b6ba'), 'light', {renderer: 'canvas'});
#                 var option_6e4435b99c8841b5ab8ff4a5be31b6ba = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 15,
#                 80
#             ],
#             "data": [
#                 {
#                     "name": "\u6df1\u5ea6\u5b66\u4e60",
#                     "value": 1351,
#                     "textStyle": {
#                         "color": "rgb(159,135,70)"
#                     }
#                 },
#                 {
#                     "name": "Unknown",
#                     "value": 820,
#                     "textStyle": {
#                         "color": "rgb(0,9,4)"
#                     }
#                 },
#                 {
#                     "name": "Python",
#                     "value": 817,
#                     "textStyle": {
#                         "color": "rgb(51,73,98)"
#                     }
#                 },
#                 {
#                     "name": "PyTorch",
#                     "value": 785,
#                     "textStyle": {
#                         "color": "rgb(114,92,70)"
#                     }
#                 },
#                 {
#                     "name": "\u7b97\u6cd5\u7814\u7a76",
#                     "value": 751,
#                     "textStyle": {
#                         "color": "rgb(156,112,52)"
#                     }
#                 },
#                 {
#                     "name": "\u81ea\u7136\u8bed\u8a00\u5904\u7406",
#                     "value": 727,
#                     "textStyle": {
#                         "color": "rgb(85,152,128)"
#                     }
#                 },
#                 {
#                     "name": "\u8bed\u8a00\u6a21\u578b",
#                     "value": 655,
#                     "textStyle": {
#                         "color": "rgb(37,53,97)"
#                     }
#                 },
#                 {
#                     "name": "\u6df1\u5ea6\u5b66\u4e60\u6846\u67b6",
#                     "value": 639,
#                     "textStyle": {
#                         "color": "rgb(87,30,18)"
#                     }
#                 },
#                 {
#                     "name": "\u7b97\u6cd5\u5f00\u53d1",
#                     "value": 551,
#                     "textStyle": {
#                         "color": "rgb(66,152,78)"
#                     }
#                 },
#                 {
#                     "name": "TensorFlow",
#                     "value": 537,
#                     "textStyle": {
#                         "color": "rgb(105,52,64)"
#                     }
#                 },
#                 {
#                     "name": "C++",
#                     "value": 403,
#                     "textStyle": {
#                         "color": "rgb(15,81,101)"
#                     }
#                 },
#                 {
#                     "name": "\u7b97\u6cd5\u4f18\u5316",
#                     "value": 368,
#                     "textStyle": {
#                         "color": "rgb(124,83,89)"
#                     }
#                 },
#                 {
#                     "name": "\u5927\u6a21\u578b",
#                     "value": 324,
#                     "textStyle": {
#                         "color": "rgb(119,99,15)"
#                     }
#                 },
#                 {
#                     "name": "\u7b97\u6cd5\u8bbe\u8ba1",
#                     "value": 298,
#                     "textStyle": {
#                         "color": "rgb(158,153,57)"
#                     }
#                 },
#                 {
#                     "name": "AI\u4eba\u5de5\u667a\u80fd\u4ea7\u54c1",
#                     "value": 274,
#                     "textStyle": {
#                         "color": "rgb(10,111,102)"
#                     }
#                 },
#                 {
#                     "name": "\u4eba\u5de5\u667a\u80fd",
#                     "value": 230,
#                     "textStyle": {
#                         "color": "rgb(12,84,108)"
#                     }
#                 },
#                 {
#                     "name": "\u4ea7\u54c1\u8bbe\u8ba1",
#                     "value": 230,
#                     "textStyle": {
#                         "color": "rgb(152,12,159)"
#                     }
#                 },
#                 {
#                     "name": "\u4ea7\u54c1\u89c4\u5212",
#                     "value": 223,
#                     "textStyle": {
#                         "color": "rgb(90,45,38)"
#                     }
#                 },
#                 {
#                     "name": "\u7528\u6237\u7814\u7a76",
#                     "value": 206,
#                     "textStyle": {
#                         "color": "rgb(100,68,26)"
#                     }
#                 },
#                 {
#                     "name": "AIGC",
#                     "value": 195,
#                     "textStyle": {
#                         "color": "rgb(152,142,132)"
#                     }
#                 },
#                 {
#                     "name": "\u4f18\u5316\u7b97\u6cd5",
#                     "value": 192,
#                     "textStyle": {
#                         "color": "rgb(3,80,114)"
#                     }
#                 },
#                 {
#                     "name": "Java",
#                     "value": 174,
#                     "textStyle": {
#                         "color": "rgb(37,119,30)"
#                     }
#                 },
#                 {
#                     "name": "C\u8bed\u8a00",
#                     "value": 162,
#                     "textStyle": {
#                         "color": "rgb(10,96,153)"
#                     }
#                 },
#                 {
#                     "name": "C/C++",
#                     "value": 161,
#                     "textStyle": {
#                         "color": "rgb(154,133,60)"
#                     }
#                 },
#                 {
#                     "name": "\u4ea7\u54c1\u4f18\u5316",
#                     "value": 151,
#                     "textStyle": {
#                         "color": "rgb(134,142,115)"
#                     }
#                 },
#                 {
#                     "name": "LLM",
#                     "value": 148,
#                     "textStyle": {
#                         "color": "rgb(160,63,3)"
#                     }
#                 },
#                 {
#                     "name": "\u6570\u636e\u5206\u6790",
#                     "value": 143,
#                     "textStyle": {
#                         "color": "rgb(75,44,35)"
#                     }
#                 },
#                 {
#                     "name": "GPT",
#                     "value": 133,
#                     "textStyle": {
#                         "color": "rgb(132,9,14)"
#                     }
#                 },
#                 {
#                     "name": "\u673a\u5668\u89c6\u89c9",
#                     "value": 131,
#                     "textStyle": {
#                         "color": "rgb(22,72,100)"
#                     }
#                 },
#                 {
#                     "name": "\u56e2\u961f\u7ba1\u7406",

# %% [markdown]
# # 组图

# %%
# page = Page(layout=Page.SimplePageLayout)
# page.add(bar,map_city_job, map_salary, bar_company, pie_edu, wordcloud)
# page.render("大模型岗位分析大屏_page.html")

# %%
# from pyecharts.charts import Page
# from pyecharts.options import TitleOpts

# # 使用可视化布局，支持拖拽调整
# page = Page(layout=Page.DraggablePageLayout)

# # 添加图表
# page.add(
#     map_city_job,   # 地图：岗位数量
#     map_salary,     # 地图：薪资
#     bar,            # 柱状图：城市岗位数
#     bar_company,    # 柱状图：公司数
#     pie_edu,        # 饼图：学历
#     wordcloud,       # 词云：岗位关键词
    
# )

# # 渲染页面，自动生成布局页面，支持拖拽调整位置和大小
# page.render("大模型岗位分析大屏.html")

# %%
# Page.save_resize_html("Awesome-pyecharts.html", cfg_file="./chart_config.json", dest="my_new_charts.html")
